# %% [markdown]
# # N-armed bandit playground

# %% [markdown]
# Import environment and necessary libraries

# %%
import gym
import gym_bandits
import numpy as np
from math import e

# %matplotlib inline
import matplotlib.pyplot as plt

episode_reward_list = []
total_reward = 0

# %% [markdown]
# Random agent on the said agent

# %%
env = gym.make("BanditTenArmedGaussian-v0")

table_q = np.ones(env.action_space.n)
table_n = np.ones(env.action_space.n)

for episode in np.arange(100):
    env.reset()
    probabilities = (e**table_q)/(np.sum(e**table_q))
    action = np.random.choice(env.action_space.n, p=probabilities)
    _, reward, _, _ = env.step(action)
    table_q[action] = table_q[action] + (reward-table_q[action])/table_n[action]
    table_n[action]+=1
    
    episode_reward_list.append((episode, reward))
    total_reward +=reward

print(table_q)
# Out:
# [-0.29716688 -0.77875844  1.59706305  1.35299559  0.09561287 -0.68622105
#   1.20680919  0.19995303  0.56298019 -1.9736905 ]

# %% [markdown]
# Visualize the data

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

eps, rews = np.array(episode_reward_list).T
smoothed_rews = running_mean(rews, 3)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='grey', alpha = 0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')

print('Total reward:',total_reward)
# Out:
# Total reward: 83.39799385192534
