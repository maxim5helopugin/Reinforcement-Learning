# %% [markdown]
# # N-armed bandit playground

# %% [markdown]
# Import environment and necessary libraries

# %%
import gym
import gym_bandits
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

episode_reward_list = []
total_reward = 0

# %% [markdown]
# Random agent on the said agent

# %%
env = gym.make("BanditTenArmedGaussian-v0")

table_q = np.zeros(env.action_space.n)
table_n = np.ones(env.action_space.n)
table_ucb = np.zeros(env.action_space.n)

for episode in range(1,100):
    env.reset()
    table_ucb = table_q + np.sqrt((2*np.log(episode))/table_n)
    action = np.argmax(table_ucb)
    _, reward, _, _ = env.step(action)
    table_q[action] = table_q[action] + (reward-table_q[action])/table_n[action]
    table_n[action]+=1
    
    episode_reward_list.append((episode, reward))
    total_reward +=reward

print(table_q)
# Out:
# [-2.12296981 -0.25173199 -1.33402056 -1.32147337  0.82325458  0.15603828
#  -1.16561327  0.1255885  -1.53345691 -0.66825856]

# %% [markdown]
# Visualize the data

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

eps, rews = np.array(episode_reward_list).T
smoothed_rews = running_mean(rews, 3)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='grey', alpha = 0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')

print('Total reward:',total_reward)
# Out:
# Total reward: 47.56752385580272
